# %% [markdown]
# # ints and floats

# %%
20 / 4
# Out:
# 5.0

# %%
4 + 4.0
# Out:
# 8.0

# %%
4 * 4.0
# Out:
# 16.0

# %%
4 ** 4.0
# Out:
# 256.0

# %%
int(4 ** 4.0)
# Out:
# 256

# %%
## when we convert from one type to another type we call casting. i'm casting fro float 256.0 to the integer 256

# %%
int(8.9)
# Out:
# 8

# %%
int(8.9999999) #int doesn't round this just take the  decimals away, we have to be very carefull with this
# Out:
# 8

# %%
int(14/3)
# Out:
# 4

# %%
round(14/3, 2) #if we want to rounf we use the round funtion, WE CAN PASS THE NUMBER OF DECIMALS THAT WE WANT TO ROUND
# Out:
# 4.67

# %%
1.2-1.0
# Out:
# 0.19999999999999996

# %%
14/3
# Out:
# 4.666666666666667

# %%
round(1.2-1.0, 2)
# Out:
# 0.2
